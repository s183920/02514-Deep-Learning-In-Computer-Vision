# %% [markdown]
# # Style GAN 2

# %%
import pickle
import torch
import sys
import os
sys.path.append(os.path.join(os.getcwd(), 'gan/code/stylegan2-ada-pytorch-main/'))
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

with open('gan/pretrained_models/ffhq.pkl', 'rb') as f:
    G = pickle.load(f)['G_ema'].cuda()  # torch.nn.Module

# %% [markdown]
# ## Example

# %%
z = torch.randn([1, G.z_dim]).cuda()    # latent codes
c = None                                # class labels (not used in this example)
# img = G(z, c)                           # NCHW, float32, dynamic range [-1, +1]

w = G.mapping(z, c, truncation_psi=0.5, truncation_cutoff=8)
img = G.synthesis(w, noise_mode='const', force_fp32=True)


plt.imshow(img[0].permute(1, 2, 0).cpu().detach().numpy())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 z = torch.randn([1, G.z_dim]).cuda()    # latent codes
#       2 c = None                                # class labels (not used in this example)
#       3 # img = G(z, c)                           # NCHW, float32, dynamic range [-1, +1]
#
# NameError: name 'torch' is not defined

# %%
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), 'gan/code/stylegan2-ada-pytorch-main/'))
import torch_utils

# %%
os.path.join(os.getcwd(), 'gan/code/stylegan2-ada-pytorch-main/torch_utils')
# Out:
# '/work3/s183920/02514-DLCI/02514-Deep-Learning-In-Computer-Vision/gan/code/stylegan2-ada-pytorch-main/torch_utils'

# %%
import os
os.getcwd()
os.environ["PYTHONPATH"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 import os
#       2 os.getcwd()
# ----> 3 os.environ["PYTHONPATH"]
#
# File /appl/python/3.10.11/lib/python3.10/os.py:680, in _Environ.__getitem__(self, key)
#     677     value = self._data[self.encodekey(key)]
#     678 except KeyError:
#     679     # raise KeyError with the original key value
# --> 680     raise KeyError(key) from None
#     681 return self.decodevalue(value)
#
# KeyError: 'PYTHONPATH'
