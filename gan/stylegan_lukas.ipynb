# %% [markdown]
# # Style GAN 2

# %%
import pickle
import torch
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '02514-Deep-Learning-In-Computer-Vision/gan/code/stylegan2-ada-pytorch-main/')) 
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import numpy as np
import PIL

# %%
# os.chdir('/zhome/c5/f/138539/02514-Deep-Learning-In-Computer-Vision/')

# %%
# os.getcwd()

# %% [markdown]
# ## Generator

# %%
with open('02514-Deep-Learning-In-Computer-Vision/gan/pretrained_models/ffhq.pkl', 'rb') as f:
    G = pickle.load(f)['G_ema'].cuda()  # torch.nn.Module

# %% [markdown]
# ### Example

# %%
z = torch.randn([1, G.z_dim]).cuda()    # latent codes
c = None                                # class labels (not used in this example)
# img = G(z, c)                           # NCHW, float32, dynamic range [-1, +1]

w = G.mapping(z, c, truncation_psi=0.5, truncation_cutoff=8)
img = G.synthesis(w, noise_mode='const', force_fp32=True)


plt.imshow(img[0].permute(1, 2, 0).cpu().detach().numpy())
plt.show()
# Out:
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"...
# ...

# %% [markdown]
# ## Project

# %%
from projector import run_projection, project

network = "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"
target = "0.png"

projected_w = project(G, img)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 6
#       3 network = "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"
#       4 target = "0.png"
# ----> 6 projected_w = project(G, img, device="cuda")
#
# File ~/02514-Deep-Learning-In-Computer-Vision/gan/code/stylegan2-ada-pytorch-main/projector.py:40, in project(G, target, num_steps, w_avg_samples, initial_learning_rate, initial_noise_factor, lr_rampdown_length, lr_rampup_length, noise_ramp_length, regularize_noise_weight, verbose, device)
#      25 def project(
#      26     G,
#      27     target: torch.Tensor, # [C,H,W] and dynamic range [0,255], W & H must match G output resolution
#    (...)
#      38     device: torch.device
#      39 ):
# ---> 40     assert target.shape == (G.img_channels, G.img_resolution, G.img_resolution)
#      42     def logprint(*args):
# ...

# %%
# read img as tensor

torch_img = torch.tensor(np.array(PIL.Image.open("gan/0.png").convert('RGB'), dtype=np.uint8).transpose([2, 0, 1]), device='cuda')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 # read img as tensor
# ----> 3 torch_img = torch.tensor(np.array(PIL.Image.open("gan/0.png").convert('RGB'), dtype=np.uint8).transpose([2, 0, 1]), device='cuda')
#
# File ~/torch/lib/python3.10/site-packages/PIL/Image.py:3236, in open(fp, mode, formats)
#    3233     filename = fp
#    3235 if filename:
# -> 3236     fp = builtins.open(filename, "rb")
#    3237     exclusive_fp = True
#    3239 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gan/0.png'

# %%
plt.imshow(torch_img.permute(1, 2, 0).cpu().detach().numpy())

# %%
import numpy as np
rep_path = "gan/results/Barbie/reconstruction/projected_w.npz"
np.load(rep_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import numpy as np
#       2 rep_path = "gan/results/Barbie/reconstruction/projected_w.npz"
# ----> 3 np.load(rep_path)
#
# File /work3/s183920/02514-DLCI/DLCI-venv/lib/python3.10/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gan/results/Barbie/reconstruction/projected_w.npz'
